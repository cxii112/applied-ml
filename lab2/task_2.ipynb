# %%
## for data
import pandas as pd
import numpy as np
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for statistical tests
import scipy
import statsmodels.formula.api as smf
import statsmodels.api as sm
## for machine learning
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition

# %%
sns.set_theme(style='darkgrid', palette=sns.color_palette('bright6'))

# %%
def utils_recognize_type(dtf, col, max_cat=20):
    if (dtf[col].dtype == "O") | (dtf[col].nunique() < max_cat):
        return "cat"
    else:
        return "num"

# %%
dtf = pd.read_csv('../assets/pokemon.csv')
dtf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pokemon_id                    1007 non-null   int64
#  1   pokemon_name                  1007 non-null   object
#  2   base_attack                   1007 non-null   int64
#  3   base_defense                  1007 non-null   int64
#  4   base_stamina                  1007 non-null   int64
#  5   type                          1007 non-null   object
#  6   rarity                        1007 non-null   object
#  7   charged_moves                 1007 non-null   object
#  8   fast_moves                    1007 non-null   object
#  9   candy_required                471 non-null    float64
#  10  distance                      1007 non-null   int64
#  11  max_cp                        1007 non-null   int64
#  12  attack_probability            904 non-null    float64
#  13  base_capture_rate             904 non-null    float64
#  14  base_flee_rate                904 non-null    float64
#  15  dodge_probability             904 non-null    float64
#  16  max_pokemon_action_frequency  904 non-null    float64
#  17  min_pokemon_action_frequency  904 non-null    float64
#  18  found_egg                     744 non-null    object
#  19  found_evolution               744 non-null    object
#  20  found_wild                    744 non-null    object
#  21  found_research                744 non-null    object
#  22  found_raid                    744 non-null    object
#  23  found_photobomb               744 non-null    object
# dtypes: float64(7), int64(6), object(11)
# memory usage: 188.9+ KB

# %%
dtf.head()
# Out:
#    pokemon_id pokemon_name  base_attack  base_defense  base_stamina  \
# 0           1    Bulbasaur          118           111           128
# 1           2      Ivysaur          151           143           155
# 2           3     Venusaur          198           189           190
# 3           4   Charmander          116            93           118
# 4           5   Charmeleon          158           126           151
#
#                   type    rarity  \
# 0  ['Grass', 'Poison']  Standard
# 1  ['Grass', 'Poison']  Standard
# 2  ['Grass', 'Poison']  Standard
# 3             ['Fire']  Standard
# 4             ['Fire']  Standard
#
#                                      charged_moves  \
# 0       ['Sludge Bomb', 'Seed Bomb', 'Power Whip']
# 1      ['Sludge Bomb', 'Solar Beam', 'Power Whip']
# 2  ['Sludge Bomb', 'Petal Blizzard', 'Solar Beam']
# 3  ['Flame Charge', 'Flame Burst', 'Flamethrower']
# 4    ['Fire Punch', 'Flame Burst', 'Flamethrower']
#
#                     fast_moves  candy_required  ...  base_flee_rate  \
# 0      ['Vine Whip', 'Tackle']             NaN  ...            -1.0
# 1  ['Razor Leaf', 'Vine Whip']            25.0  ...            -1.0
# 2  ['Razor Leaf', 'Vine Whip']           100.0  ...            -1.0
# 3         ['Ember', 'Scratch']             NaN  ...            -1.0
# 4       ['Ember', 'Fire Fang']            25.0  ...            -1.0
#
#    dodge_probability  max_pokemon_action_frequency  \
# 0               0.15                           1.6
# 1               0.15                           1.6
# 2               0.15                           1.6
# 3               0.15                           1.6
# 4               0.15                           1.6
#
#    min_pokemon_action_frequency  found_egg  found_evolution  found_wild  \
# 0                           0.2       True            False        True
# 1                           0.2      False             True        True
# 2                           0.2      False             True        True
# 3                           0.2       True            False        True
# 4                           0.2      False             True        True
#
#    found_research found_raid found_photobomb
# 0            True       True            True
# 1            True       True            True
# 2            True       True            True
# 3            True       True            True
# 4            True       True            True
#
# [5 rows x 24 columns]

# %%
dtf.type.unique()
# Out:
# array(["['Grass', 'Poison']", "['Fire']", "['Fire', 'Flying']",
#        "['Water']", "['Bug']", "['Bug', 'Flying']", "['Bug', 'Poison']",
#        "['Normal', 'Flying']", "['Dark', 'Normal']", "['Poison']",
#        "['Electric']", "['Electric', 'Psychic']", "['Ice', 'Steel']",
#        "['Poison', 'Ground']", "['Fairy']", "['Ice']", "['Ice', 'Fairy']",
#        "['Normal', 'Fairy']", "['Poison', 'Flying']", "['Bug', 'Grass']",
#        "['Ground', 'Steel']", "['Dark']", "['Fighting']",
#        "['Fire', 'Rock']", "['Water', 'Fighting']", "['Psychic']",
#        "['Water', 'Poison']", "['Rock', 'Electric']",
#        "['Psychic', 'Fairy']", "['Water', 'Psychic']",
#        "['Electric', 'Steel']", "['Water', 'Ice']", "['Poison', 'Dark']",
#        "['Ghost', 'Poison']", "['Rock', 'Ground']",
#        "['Electric', 'Grass']", "['Grass', 'Psychic']",
#        "['Grass', 'Dragon']", "['Ground']", "['Fire', 'Ghost']",
#        "['Normal']", "['Poison', 'Fairy']", "['Ground', 'Rock']",
#        "['Grass']", "['Ice', 'Psychic']", "['Water', 'Flying']",
#        "['Rock', 'Water']", "['Rock', 'Flying']", "['Psychic', 'Flying']",
#        "['Fighting', 'Flying']", "['Dark', 'Flying']", "['Dragon']",
#        "['Dragon', 'Flying']", "['Water', 'Electric']",
#        "['Fairy', 'Flying']", "['Water', 'Fairy']", "['Rock']",
#        "['Grass', 'Flying']", "['Water', 'Ground']", "['Ghost']",
#        "['Normal', 'Psychic']", "['Bug', 'Steel']",
#        "['Ground', 'Flying']", "['Steel', 'Ground']",
#        "['Dark', 'Poison']", "['Bug', 'Rock']", "['Bug', 'Fighting']",
#        "['Fighting', 'Poison']", "['Ice', 'Ground']", "['Water', 'Rock']",
#        "['Ice', 'Flying']", "['Steel', 'Flying']", "['Dark', 'Fire']",
#        "['Water', 'Dragon']", "['Rock', 'Dark']", "['Psychic', 'Grass']",
#        "['Fire', 'Fighting']", "['Water', 'Grass']", "['Grass', 'Dark']",
#        "['Bug', 'Water']", "['Grass', 'Fighting']", "['Bug', 'Ground']",
#        "['Bug', 'Ghost']", "['Dark', 'Ghost']", "['Steel', 'Fairy']",
#        "['Steel', 'Rock']", "['Fighting', 'Psychic']",
#        "['Water', 'Dark']", "['Fire', 'Ground']", "['Ground', 'Dragon']",
#        "['Rock', 'Psychic']", "['Ground', 'Psychic']",
#        "['Rock', 'Grass']", "['Rock', 'Bug']", "['Ice', 'Water']",
#        "['Steel', 'Psychic']", "['Steel']", "['Dragon', 'Psychic']",
#        "['Grass', 'Ground']", "['Water', 'Steel']", "['Normal', 'Water']",
#        "['Rock', 'Steel']", "['Ghost', 'Flying']", "['Ghost', 'Dark']",
#        "['Dragon', 'Ground']", "['Fighting', 'Steel']",
#        "['Poison', 'Bug']", "['Poison', 'Fighting']", "['Grass', 'Ice']",
#        "['Dark', 'Ice']", "['Psychic', 'Fighting']", "['Ice', 'Ghost']",
#        "['Electric', 'Flying']", "['Steel', 'Dragon']",
#        "['Fire', 'Steel']", "['Ghost', 'Dragon']", "['Psychic', 'Fire']",
#        "['Grass', 'Fairy']", "['Ground', 'Dark']", "['Dark', 'Fighting']",
#        "['Ground', 'Ghost']", "['Normal', 'Grass']", "['Water', 'Ghost']",
#        "['Bug', 'Electric']", "['Grass', 'Steel']", "['Ghost', 'Fire']",
#        "['Dark', 'Steel']", "['Dark', 'Dragon']", "['Bug', 'Fire']",
#        "['Steel', 'Fighting']", "['Rock', 'Fighting']", "['Flying']",
#        "['Dragon', 'Fire']", "['Dragon', 'Electric']",
#        "['Dragon', 'Ice']", "['Fire', 'Psychic']", "['Normal', 'Ground']",
#        "['Fire', 'Normal']", "['Fighting', 'Dark']", "['Steel', 'Ghost']",
#        "['Dark', 'Psychic']", "['Poison', 'Water']",
#        "['Poison', 'Dragon']", "['Electric', 'Normal']",
#        "['Rock', 'Dragon']", "['Rock', 'Ice']", "['Electric', 'Fairy']",
#        "['Rock', 'Fairy']", "['Ghost', 'Grass']", "['Ice', 'Rock']",
#        "['Flying', 'Dragon']", "['Psychic', 'Ghost']",
#        "['Fire', 'Water']", "['Fire', 'Dark']", "['Fighting', 'Ice']",
#        "['Bug', 'Fairy']", "['Water', 'Bug']", "['Poison', 'Fire']",
#        "['Normal', 'Fighting']", "['Ghost', 'Ground']",
#        "['Fire', 'Dragon']", "['Ghost', 'Fairy']", "['Normal', 'Dragon']",
#        "['Dragon', 'Fighting']", "['Psychic', 'Steel']",
#        "['Rock', 'Poison']", "['Fighting', 'Ghost']",
#        "['Flying', 'Steel']", "['Bug', 'Psychic']", "['Rock', 'Fire']",
#        "['Flying', 'Water']", "['Electric', 'Poison']", "['Fire', 'Bug']",
#        "['Dark', 'Fairy']", "['Ice', 'Bug']", "['Psychic', 'Normal']",
#        "['Electric', 'Dark']", "['Electric', 'Dragon']",
#        "['Electric', 'Ice']", "['Dragon', 'Ghost']", "['Fairy', 'Steel']",
#        "['Fighting', 'Water']", "['Dark', 'Grass']", "['Psychic', 'Ice']",
#        "['Ground', 'Normal']", "['Bug', 'Dark']",
#        "['Electric', 'Fighting']", "['Grass', 'Normal']",
#        "['Poison', 'Normal']", "['Grass', 'Ghost']",
#        "['Ground', 'Grass']", "['Grass', 'Fire']", "['Flying', 'Dark']",
#        "['Steel', 'Poison']", "['Dragon', 'Normal']",
#        "['Flying', 'Fighting']", "['Dragon', 'Water']",
#        "['Ground', 'Fighting']", "['Fairy', 'Psychic']",
#        "['Electric', 'Ground']", "['Fighting', 'Electric']",
#        "['Fire', 'Poison']", "['Dark', 'Ground']", "['Dragon', 'Dark']",
#        "['Fairy', 'Fighting']", "['Fighting', 'Dragon']"], dtype=object)

# %%
def str_to_str_list(src: str) -> str:
    res = []
    s = src.replace('[', '').replace(']','').replace(", ", ",").replace("'", "")
    res = s.split(',')
    return res

# %%
def flatten_list(src: list) -> list:
    return [ x for xs in src for x in xs]

# %%
dtf.type.unique()
# Out:
# array(["['Grass', 'Poison']", "['Fire']", "['Fire', 'Flying']",
#        "['Water']", "['Bug']", "['Bug', 'Flying']", "['Bug', 'Poison']",
#        "['Normal', 'Flying']", "['Dark', 'Normal']", "['Poison']",
#        "['Electric']", "['Electric', 'Psychic']", "['Ice', 'Steel']",
#        "['Poison', 'Ground']", "['Fairy']", "['Ice']", "['Ice', 'Fairy']",
#        "['Normal', 'Fairy']", "['Poison', 'Flying']", "['Bug', 'Grass']",
#        "['Ground', 'Steel']", "['Dark']", "['Fighting']",
#        "['Fire', 'Rock']", "['Water', 'Fighting']", "['Psychic']",
#        "['Water', 'Poison']", "['Rock', 'Electric']",
#        "['Psychic', 'Fairy']", "['Water', 'Psychic']",
#        "['Electric', 'Steel']", "['Water', 'Ice']", "['Poison', 'Dark']",
#        "['Ghost', 'Poison']", "['Rock', 'Ground']",
#        "['Electric', 'Grass']", "['Grass', 'Psychic']",
#        "['Grass', 'Dragon']", "['Ground']", "['Fire', 'Ghost']",
#        "['Normal']", "['Poison', 'Fairy']", "['Ground', 'Rock']",
#        "['Grass']", "['Ice', 'Psychic']", "['Water', 'Flying']",
#        "['Rock', 'Water']", "['Rock', 'Flying']", "['Psychic', 'Flying']",
#        "['Fighting', 'Flying']", "['Dark', 'Flying']", "['Dragon']",
#        "['Dragon', 'Flying']", "['Water', 'Electric']",
#        "['Fairy', 'Flying']", "['Water', 'Fairy']", "['Rock']",
#        "['Grass', 'Flying']", "['Water', 'Ground']", "['Ghost']",
#        "['Normal', 'Psychic']", "['Bug', 'Steel']",
#        "['Ground', 'Flying']", "['Steel', 'Ground']",
#        "['Dark', 'Poison']", "['Bug', 'Rock']", "['Bug', 'Fighting']",
#        "['Fighting', 'Poison']", "['Ice', 'Ground']", "['Water', 'Rock']",
#        "['Ice', 'Flying']", "['Steel', 'Flying']", "['Dark', 'Fire']",
#        "['Water', 'Dragon']", "['Rock', 'Dark']", "['Psychic', 'Grass']",
#        "['Fire', 'Fighting']", "['Water', 'Grass']", "['Grass', 'Dark']",
#        "['Bug', 'Water']", "['Grass', 'Fighting']", "['Bug', 'Ground']",
#        "['Bug', 'Ghost']", "['Dark', 'Ghost']", "['Steel', 'Fairy']",
#        "['Steel', 'Rock']", "['Fighting', 'Psychic']",
#        "['Water', 'Dark']", "['Fire', 'Ground']", "['Ground', 'Dragon']",
#        "['Rock', 'Psychic']", "['Ground', 'Psychic']",
#        "['Rock', 'Grass']", "['Rock', 'Bug']", "['Ice', 'Water']",
#        "['Steel', 'Psychic']", "['Steel']", "['Dragon', 'Psychic']",
#        "['Grass', 'Ground']", "['Water', 'Steel']", "['Normal', 'Water']",
#        "['Rock', 'Steel']", "['Ghost', 'Flying']", "['Ghost', 'Dark']",
#        "['Dragon', 'Ground']", "['Fighting', 'Steel']",
#        "['Poison', 'Bug']", "['Poison', 'Fighting']", "['Grass', 'Ice']",
#        "['Dark', 'Ice']", "['Psychic', 'Fighting']", "['Ice', 'Ghost']",
#        "['Electric', 'Flying']", "['Steel', 'Dragon']",
#        "['Fire', 'Steel']", "['Ghost', 'Dragon']", "['Psychic', 'Fire']",
#        "['Grass', 'Fairy']", "['Ground', 'Dark']", "['Dark', 'Fighting']",
#        "['Ground', 'Ghost']", "['Normal', 'Grass']", "['Water', 'Ghost']",
#        "['Bug', 'Electric']", "['Grass', 'Steel']", "['Ghost', 'Fire']",
#        "['Dark', 'Steel']", "['Dark', 'Dragon']", "['Bug', 'Fire']",
#        "['Steel', 'Fighting']", "['Rock', 'Fighting']", "['Flying']",
#        "['Dragon', 'Fire']", "['Dragon', 'Electric']",
#        "['Dragon', 'Ice']", "['Fire', 'Psychic']", "['Normal', 'Ground']",
#        "['Fire', 'Normal']", "['Fighting', 'Dark']", "['Steel', 'Ghost']",
#        "['Dark', 'Psychic']", "['Poison', 'Water']",
#        "['Poison', 'Dragon']", "['Electric', 'Normal']",
#        "['Rock', 'Dragon']", "['Rock', 'Ice']", "['Electric', 'Fairy']",
#        "['Rock', 'Fairy']", "['Ghost', 'Grass']", "['Ice', 'Rock']",
#        "['Flying', 'Dragon']", "['Psychic', 'Ghost']",
#        "['Fire', 'Water']", "['Fire', 'Dark']", "['Fighting', 'Ice']",
#        "['Bug', 'Fairy']", "['Water', 'Bug']", "['Poison', 'Fire']",
#        "['Normal', 'Fighting']", "['Ghost', 'Ground']",
#        "['Fire', 'Dragon']", "['Ghost', 'Fairy']", "['Normal', 'Dragon']",
#        "['Dragon', 'Fighting']", "['Psychic', 'Steel']",
#        "['Rock', 'Poison']", "['Fighting', 'Ghost']",
#        "['Flying', 'Steel']", "['Bug', 'Psychic']", "['Rock', 'Fire']",
#        "['Flying', 'Water']", "['Electric', 'Poison']", "['Fire', 'Bug']",
#        "['Dark', 'Fairy']", "['Ice', 'Bug']", "['Psychic', 'Normal']",
#        "['Electric', 'Dark']", "['Electric', 'Dragon']",
#        "['Electric', 'Ice']", "['Dragon', 'Ghost']", "['Fairy', 'Steel']",
#        "['Fighting', 'Water']", "['Dark', 'Grass']", "['Psychic', 'Ice']",
#        "['Ground', 'Normal']", "['Bug', 'Dark']",
#        "['Electric', 'Fighting']", "['Grass', 'Normal']",
#        "['Poison', 'Normal']", "['Grass', 'Ghost']",
#        "['Ground', 'Grass']", "['Grass', 'Fire']", "['Flying', 'Dark']",
#        "['Steel', 'Poison']", "['Dragon', 'Normal']",
#        "['Flying', 'Fighting']", "['Dragon', 'Water']",
#        "['Ground', 'Fighting']", "['Fairy', 'Psychic']",
#        "['Electric', 'Ground']", "['Fighting', 'Electric']",
#        "['Fire', 'Poison']", "['Dark', 'Ground']", "['Dragon', 'Dark']",
#        "['Fairy', 'Fighting']", "['Fighting', 'Dragon']"], dtype=object)

# %%
types = set(flatten_list([str_to_str_list(x) for x in dtf.type.unique()]))
types
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water'}

# %%
dtf['type'] = [str_to_str_list(x) for x in list(dtf.type)]

# %%
dtf.type
# Out:
# 0          [Grass, Poison]
# 1          [Grass, Poison]
# 2          [Grass, Poison]
# 3                   [Fire]
# 4                   [Fire]
#                ...
# 1002          [Dark, Fire]
# 1003        [Dragon, Dark]
# 1004     [Fairy, Fighting]
# 1005    [Fighting, Dragon]
# 1006    [Electric, Dragon]
# Name: type, Length: 1007, dtype: object

# %%
for type in types:
    M = [type]
    dtf['Is'+type] = dtf.type.isin(M)

# %%
for type in types:
    M = [type]
    print(M)
# Out:
# ['Grass']
# ['Ground']
# ['Normal']
# ['Ghost']
# ['Bug']
# ['Water']
# ['Flying']
# ['Steel']
# ['Fairy']
# ['Dark']
# ['Electric']
# ['Poison']
# ['Ice']
# ['Rock']
# ['Psychic']
# ['Fire']
# ['Dragon']
# ['Fighting']

# %%
dtf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pokemon_id                    1007 non-null   int64
#  1   pokemon_name                  1007 non-null   object
#  2   base_attack                   1007 non-null   int64
#  3   base_defense                  1007 non-null   int64
#  4   base_stamina                  1007 non-null   int64
#  5   type                          1007 non-null   object
#  6   rarity                        1007 non-null   object
#  7   charged_moves                 1007 non-null   object
#  8   fast_moves                    1007 non-null   object
#  9   candy_required                471 non-null    float64
#  10  distance                      1007 non-null   int64
#  11  max_cp                        1007 non-null   int64
#  12  attack_probability            904 non-null    float64
#  13  base_capture_rate             904 non-null    float64
#  14  base_flee_rate                904 non-null    float64
#  15  dodge_probability             904 non-null    float64
#  16  max_pokemon_action_frequency  904 non-null    float64
#  17  min_pokemon_action_frequency  904 non-null    float64
#  18  found_egg                     744 non-null    object
#  19  found_evolution               744 non-null    object
#  20  found_wild                    744 non-null    object
#  21  found_research                744 non-null    object
#  22  found_raid                    744 non-null    object
#  23  found_photobomb               744 non-null    object
#  24  IsGrass                       1007 non-null   bool
#  25  IsGround                      1007 non-null   bool
#  26  IsNormal                      1007 non-null   bool
#  27  IsGhost                       1007 non-null   bool
#  28  IsBug                         1007 non-null   bool
#  29  IsWater                       1007 non-null   bool
#  30  IsFlying                      1007 non-null   bool
#  31  IsSteel                       1007 non-null   bool
#  32  IsFairy                       1007 non-null   bool
#  33  IsDark                        1007 non-null   bool
#  34  IsElectric                    1007 non-null   bool
#  35  IsPoison                      1007 non-null   bool
#  36  IsIce                         1007 non-null   bool
#  37  IsRock                        1007 non-null   bool
#  38  IsPsychic                     1007 non-null   bool
#  39  IsFire                        1007 non-null   bool
#  40  IsDragon                      1007 non-null   bool
#  41  IsFighting                    1007 non-null   bool
# dtypes: bool(18), float64(7), int64(6), object(11)
# memory usage: 206.6+ KB

# %%
dtf.head()
# Out:
#    pokemon_id pokemon_name  base_attack  base_defense  base_stamina  \
# 0           1    Bulbasaur          118           111           128
# 1           2      Ivysaur          151           143           155
# 2           3     Venusaur          198           189           190
# 3           4   Charmander          116            93           118
# 4           5   Charmeleon          158           126           151
#
#               type    rarity                                    charged_moves  \
# 0  [Grass, Poison]  Standard       ['Sludge Bomb', 'Seed Bomb', 'Power Whip']
# 1  [Grass, Poison]  Standard      ['Sludge Bomb', 'Solar Beam', 'Power Whip']
# 2  [Grass, Poison]  Standard  ['Sludge Bomb', 'Petal Blizzard', 'Solar Beam']
# 3           [Fire]  Standard  ['Flame Charge', 'Flame Burst', 'Flamethrower']
# 4           [Fire]  Standard    ['Fire Punch', 'Flame Burst', 'Flamethrower']
#
#                     fast_moves  candy_required  ...  IsFairy  IsDark  \
# 0      ['Vine Whip', 'Tackle']             NaN  ...    False   False
# 1  ['Razor Leaf', 'Vine Whip']            25.0  ...    False   False
# 2  ['Razor Leaf', 'Vine Whip']           100.0  ...    False   False
# 3         ['Ember', 'Scratch']             NaN  ...    False   False
# 4       ['Ember', 'Fire Fang']            25.0  ...    False   False
#
#    IsElectric  IsPoison  IsIce  IsRock  IsPsychic  IsFire IsDragon IsFighting
# 0       False     False  False   False      False   False    False      False
# 1       False     False  False   False      False   False    False      False
# 2       False     False  False   False      False   False    False      False
# 3       False     False  False   False      False   False    False      False
# 4       False     False  False   False      False   False    False      False
#
# [5 rows x 42 columns]

# %%
dtf.to_csv('unfolded.csv')
